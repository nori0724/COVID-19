# %%
library(openxlsx)
library(psych)

# %%
df <- read.xlsx("../../data/data_covid_fix_name.xlsx")

# %%
head(df)
# Out:
#   country   pop      urb    gdp       dist     hf   pf       ef   date_first
# 1 Albania    2866376 60.319 13364.155  6996524 7.84 8.005411 7.67 70
# 2 Algeria   42228429 72.629 15481.788  9108277 4.99 5.201489 4.77 58
# 3 Angola    30809762 65.514  6452.355 10490120 5.40 5.979936 4.83 83
# 4 Argentina 44494502 91.870 20610.569 19025624 6.86 8.044600 5.67 65
# 5 Armenia    2951776 63.149 10343.176  5064044 7.42 7.145017 7.70 62
# 6 Australia 24992369 86.012 51663.365  7608913 8.62 9.160533 8.07 26
#   detection status cumul  air
# 1 74.3      1      108641   303.14
# 2 12.0      1       80272  6442.44
# 3 17.9      1      303691    76.94
# 4 74.9      1       92122  1516.63
# 5 60.8      1       86276       NA
# 6 97.3      1        1347 75667.65

# %%
getwd()
# Out:
# [1] "/Users/masanoritakahashi/Documents/講義/ゼミ/M2/空間生存時間/COVID-19/notebook/探索的データ解析"

# %%
png("plot/散布図行列.png")
psych::pairs.panels(df[,c(9,2,3,4,5,6,7,8,10,13)])
dev.off()
# Out:
# pdf
#   2

# %%
df[,c(9,2,3,4,5,6,7,8,10,11,13)]
# Out:
#     date_first pop       urb     gdp        dist     hf   pf       ef
# 1   70           2866376 60.319  13364.1554  6996524 7.84 8.005411 7.67
# 2   58          42228429 72.629  15481.7876  9108277 4.99 5.201489 4.77
# 3   83          30809762 65.514   6452.3552 10490120 5.40 5.979936 4.83
# 4   65          44494502 91.870  20610.5685 19025624 6.86 8.044600 5.67
# 5   62           2951776 63.149  10343.1756  5064044 7.42 7.145017 7.70
# 6   26          24992369 86.012  51663.3651  7608913 8.62 9.160533 8.07
# 7   58           8847037 58.297  55454.6893  7103537 8.48 9.245685 7.71
# 8   61           9942334 55.680  18044.1368  4849217 6.22 6.104661 6.34
# 9   77            385640 83.025  32087.7292 13276138 7.56 7.871205 7.25
# 10  56           1569439 89.287  47303.0485  5138295 6.63 5.910895 7.35
# 11  70         161356039 36.632   4371.7550  1918841 5.77 5.365573 6.18
# 12  79            286641 31.147  18554.1293 14231260 7.02 7.589752 6.45
# ...

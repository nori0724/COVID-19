# %%
# 参考：統計科学研究所_R_主成分分析.ppt
# https://statistics.co.jp/reference/software_R/statR_9_principal.pdf

# %%
library(openxlsx)

# %%
df <- read.xlsx("/Users/masanoritakahashi/Documents/講義/ゼミ/M2/空間生存時間/COVID-19/data/data_covid_fix_name.xlsx")

# %%
df <- na.omit(df)
# index reset
rownames(df) <- 1:nrow(df)
head(df)
# Out:
#   country   pop      urb    gdp       dist     hf   pf       ef   date_first
# 1 Albania    2866376 60.319 13364.155  6996524 7.84 8.005411 7.67 70
# 2 Algeria   42228429 72.629 15481.788  9108277 4.99 5.201489 4.77 58
# 3 Angola    30809762 65.514  6452.355 10490120 5.40 5.979936 4.83 83
# 4 Argentina 44494502 91.870 20610.569 19025624 6.86 8.044600 5.67 65
# 5 Australia 24992369 86.012 51663.365  7608913 8.62 9.160533 8.07 26
# 6 Austria    8847037 58.297 55454.689  7103537 8.48 9.245685 7.71 58
#   detection status cumul  air
# 1 74.3      1      108641   303.14
# 2 12.0      1       80272  6442.44
# 3 17.9      1      303691    76.94
# 4 74.9      1       92122  1516.63
# 5 97.3      1        1347 75667.65
# 6 73.2      1       80272 12935.50

# %%
data = df[,c(2,3,4,5,7,8,10,13)]
head(data)
# Out:
#   pop      urb    gdp       dist     pf       ef   detection air
# 1  2866376 60.319 13364.155  6996524 8.005411 7.67 74.3        303.14
# 2 42228429 72.629 15481.788  9108277 5.201489 4.77 12.0       6442.44
# 3 30809762 65.514  6452.355 10490120 5.979936 4.83 17.9         76.94
# 4 44494502 91.870 20610.569 19025624 8.044600 5.67 74.9       1516.63
# 5 24992369 86.012 51663.365  7608913 9.160533 8.07 97.3      75667.65
# 6  8847037 58.297 55454.689  7103537 9.245685 7.71 73.2      12935.50

# %%
#data["pop"] = log(data["pop"])
#data["air"] = log(data["air"])
#data["gdp"] = log(data["gdp"])

# 標準化
data_scale = scale(data)

# %% [markdown]
# # 主成分分析

# %% [markdown]
# #### 引数 “scale” について
# - 関数 “prcomp” に、引数 “scale=T” を指定
# ⇒ 相関行列から主成分分析を行う
# - 関数 “prcomp” に、引数 “scale=F” を指定
# ⇒ 分散共分散行列から主成分分析を行う

# %% [markdown]
# #### 分析結果に関数 “summary” を適用
# - Standard deviation (標準偏差)
# - Proportion of Variance (寄与率)
# - Cumulative Proportion (累積寄与率)

# %%
result <- prcomp(data_scale, scale=T)
summary(result)

# 第4主成分までで81%を説明
# Out:
# Importance of components:
#                           PC1    PC2   PC3    PC4     PC5     PC6     PC7
# Standard deviation     1.7432 1.2202 1.020 0.9579 0.74199 0.69075 0.51827
# Proportion of Variance 0.3799 0.1861 0.130 0.1147 0.06882 0.05964 0.03358
# Cumulative Proportion  0.3799 0.5660 0.696 0.8107 0.87952 0.93917 0.97274
#                            PC8
# Standard deviation     0.46697
# Proportion of Variance 0.02726
# Cumulative Proportion  1.00000

# %% [markdown]
# ## 固有ベクトルの出力

# %%
round(result$rotation, 3)
# Out:
#           PC1    PC2    PC3    PC4    PC5    PC6    PC7    PC8
# pop        0.016  0.667 -0.288  0.032 -0.609 -0.300 -0.006  0.100
# urb        0.385 -0.262 -0.193  0.542 -0.053 -0.390 -0.026 -0.544
# gdp        0.448 -0.089  0.166  0.497 -0.101  0.154  0.045  0.693
# dist      -0.090 -0.404 -0.807 -0.137  0.009 -0.047 -0.227  0.324
# pf         0.436 -0.206 -0.107 -0.436 -0.262  0.112  0.692 -0.078
# ef         0.468 -0.045  0.123 -0.322 -0.287  0.311 -0.671 -0.174
# detection  0.406  0.193  0.069 -0.350  0.503 -0.603 -0.098  0.209
# air        0.261  0.484 -0.412  0.150  0.461  0.509  0.084 -0.167

# %% [markdown]
# ## 因子負荷量
#  プログラムの概略
# - １行目 ： 因子負荷量の計算
# 固有ベクトル（result$rotation）と、対応した固有値の平方根（result$sdev）との積をとる
# - sweep 関数の使い方は、apply 関数とよく似ている
# 参考URL : R-Tips 24節 「applyファミリー」
# http://cse.naro.affrc.go.jp/takezawa/r-tips/r/24.html

# %% [markdown]
# ### 目的
# - 主成分に強く寄与している変数を見つけることが重要
# - 因子負荷量が１か-1に近い因子ほど、主成分に強く寄与している
# - 因子負荷量をプロットすることにより、 主成分に寄与している因子を視覚的に捉えることができる

# %%
fc.l <- sweep(result$rotation, MARGIN=2, result$sdev, FUN="*")
col <- c("Pop", "urb", "gdp", "dist", "pf", "ef", "detection", "air")
plot(fc.l[,1], pch=col, ylim=c(-1,1), main="PC1")
plot(fc.l[,2], pch=col, ylim=c(-1,1), main="PC2")
plot(fc.l[,3], pch=col, ylim=c(-1,1), main="PC3")
plot(fc.l[,4], pch=col, ylim=c(-1,1), main="PC4")
# Out:
# Plot with title “PC1”
# Plot with title “PC2”
# Plot with title “PC3”
# Plot with title “PC4”

# %% [markdown]
# ### 因子負荷量の解釈(2次元)

# %% [markdown]
# - 第１主成分に強く寄与するが、第２主成分にはほとんど寄与しない因子
# urb, pf, gdp, ef, dist
# - 第２主成分に強く寄与する因子
# Pop

# %%
plot(fc.l[,1], fc.l[,2], pch=col, xlim=c(-1,1), ylim=c(-1,1), main="PC1, PC2")
# Out:
# Plot with title “PC1, PC2”

# %% [markdown]
# ## 主成分得点plot

# %% [markdown]
# - 主成分得点を低次元空間にプロットすると、個体の特徴や位置を把握しやすくなる
# - 「R」では、biplot 関数を適用することで、解釈しやすい形で主成分得点のプロットを得ることができる

# %%
biplot(result)
# Out:
# plot without title

# %% [markdown]
# ### 参考
# - 理論
# http://cogpsy.educ.kyoto-u.ac.jp/personal/Kusumi/datasem11/osanai.pdf
# - 実装
# https://www.juen.ac.jp/lab/okumura/handout/160201R%E3%81%AB%E3%82%88%E3%82%8B%E5%9B%A0%E5%AD%90%E5%88%86%E6%9E%90.pages.pdf

# %%
install.packages("rworldmap")
library(rworldmap)
# Out:
# The downloaded binary packages are in
# 	/var/folders/jb/jxztdls55vncm84hp50zf9n40000gn/T//RtmpKipRIS/downloaded_packages
# Loading required package: sp
#
# ### Welcome to rworldmap ###
#
# For a short introduction type : 	 vignette('rworldmap')

# %%
library(openxlsx)
library(corrplot)
# Out:
# corrplot 0.84 loaded

# %%
df <- read.xlsx("../data/data_covid_fix_name.xlsx")

# %%
df <- df[, colnames(df) != "cumul"]

# %%
df <- na.omit(df)
# index reset
rownames(df) <- 1:nrow(df)
head(df)
# Out:
#   country   pop      urb    gdp       dist     hf   pf       ef   date_first
# 1 Albania    2866376 60.319 13364.155  6996524 7.84 8.005411 7.67 70
# 2 Algeria   42228429 72.629 15481.788  9108277 4.99 5.201489 4.77 58
# 3 Angola    30809762 65.514  6452.355 10490120 5.40 5.979936 4.83 83
# 4 Argentina 44494502 91.870 20610.569 19025624 6.86 8.044600 5.67 65
# 5 Australia 24992369 86.012 51663.365  7608913 8.62 9.160533 8.07 26
# 6 Austria    8847037 58.297 55454.689  7103537 8.48 9.245685 7.71 58
#   detection status air
# 1 74.3      1        303.14
# 2 12.0      1       6442.44
# 3 17.9      1         76.94
# 4 74.9      1       1516.63
# 5 97.3      1      75667.65
# 6 73.2      1      12935.50

# %%
data = df[,c(2,3,4,5,6,9,10,12)]

# log
data = log(data)
# 標準化
data= scale(data)

head(data)
# Out:
#   pop        urb        gdp         dist        hf          date_first
# 1 -0.8304081 0.14522960  0.00803967 -0.10000665  0.83937737  0.40068236
# 2  0.8179593 0.55943437  0.13185308  0.37723785 -1.86965358 -0.09390578
# 3  0.6247775 0.32948958 -0.60487411  0.63280474 -1.39618757  0.84870044
# 4  0.8499898 1.08357748  0.37271488  1.70998847  0.03871705  0.20577415
# 5  0.4965495 0.93662818  1.14624886  0.05180777  1.40807981 -2.20412299
# 6 -0.1398002 0.06918419  1.20586029 -0.07254229  1.30989675 -0.09390578
#   detection  air
# 1  0.9784892 -0.7001144
# 2 -2.1891023  0.4308812
# 3 -1.4943360 -1.2074928
# 4  0.9924628 -0.1043414
# 5  1.4470387  1.3424378
# 6  0.9525753  0.6888197

# %%
# logなしの分布
library(psych)
psych::pairs.panels(df[,c(2,3,4,5,6,9,10,12)])
# Out:
# plot without title

# %%
# 全部logをとった分布
psych::pairs.panels(data)
# Out:
# plot without title

# %%
# 相関行列
cor_matrix = cor(data)
round(cor_matrix, 2)
# Out:
#            pop   urb   gdp   dist  hf    date_first detection air
# pop         1.00 -0.11 -0.07 -0.16 -0.07 -0.26       0.10      0.39
# urb        -0.11  1.00  0.66  0.12  0.41 -0.36       0.29      0.18
# gdp        -0.07  0.66  1.00 -0.23  0.50 -0.45       0.34      0.28
# dist       -0.16  0.12 -0.23  1.00  0.00  0.38      -0.20     -0.06
# hf         -0.07  0.41  0.50  0.00  1.00 -0.38       0.54      0.21
# date_first -0.26 -0.36 -0.45  0.38 -0.38  1.00      -0.54     -0.42
# detection   0.10  0.29  0.34 -0.20  0.54 -0.54       1.00      0.35
# air         0.39  0.18  0.28 -0.06  0.21 -0.42       0.35      1.00

# %%
# urb - gdp (0.75)
# detection - hf (0.52)
# air - date_first (-0.61)
corrplot(cor_matrix)
# Out:
# Plot with title “”

# %%
corrplot(cor_matrix, method="shade", shade.col=NA, tl.col="black", tl.srt=45,, addCoef.col="black", addcolorlabel="no", order="AOE")
# Out:
# Plot with title “”

# %%
# 固有値
eigenvalue　= eigen(cor_matrix)$values
print(eigenvalue)
# Out:
# [1] 3.2940895 1.8139078 0.9550529 0.8506228 0.4465154 0.2992735 0.2103101
# [8] 0.1302280

# %%
# 固有ベクトル
eigenvector　= eigen(cor_matrix)$vectors
eigenvector
# Out:
#      [,1]       [,2]       [,3]        [,4]        [,5]        [,6]
# [1,] -0.1101945  0.6021132  0.37923281  0.33290730  0.01672323 -0.03692528
# [2,] -0.3457896 -0.3890415  0.44260838 -0.15011569  0.20900561 -0.46377227
# [3,] -0.4510701 -0.3017049  0.10691483 -0.28538511  0.06413042  0.13021587
# [4,]  0.1786327 -0.3906701  0.48211330  0.63503899 -0.26090395  0.02074917
# [5,] -0.3388959 -0.3337128 -0.44309998  0.35230334 -0.32181234  0.29466419
# [6,]  0.4146963 -0.2794451  0.04856175  0.08118728  0.69186572  0.41580075
# [7,] -0.3819424  0.1044106 -0.33972915  0.49939228  0.54213713 -0.28663592
# [8,] -0.4474476  0.2051878  0.31985083 -0.04262807  0.08774613  0.65137370
#      [,7]        [,8]
# [1,] -0.52614993  0.30363663
# [2,] -0.32851405 -0.37940713
# [3,]  0.08004694  0.76495625
# [4,]  0.31625210  0.10603141
# [5,] -0.50109385 -0.10883428
# [6,] -0.29301114  0.05969747
# [7,]  0.31929542  0.01968484
# [8,]  0.26442717 -0.38943306

# %%
# スクリープロット
# 固有値の1以上の数を観察(この場合2)
# 固有値の1以上の数が共通因子の数に関係する
plot(eigenvalue, type="b", main="Scree Plot", xlab="Number", ylab="Eigenvalue")
# Out:
# Plot with title “Scree Plot”

# %% [markdown]
# # 因子分析

# %%
# 因子の回転法を“varimax”もしくは“promax”から選択する。回転させない場合は“none”と指定。
# factor：共通因子の数を指定する。
# scores:回帰方法 (regression) とバートレット法 (Bartlett) 
fit0<- factanal(x=data, factors=3, rotation="none",scores="Bartlett")
fit1<- factanal(x=data, factors=3, rotation="varimax",scores="Bartlett")
fit2<- factanal(x=data, factors=3, rotation="promax",scores="Bartlett")

# %% [markdown]
# #### 結果の読み取り
# - loadings　因子負荷量
# - correlation　相関係数
# - factors　求めた因子数
# - STATISTIC　カイ2乗値
# - dof　カイ2乗決定の自由度
# - PVAL　カイ2乗統計量のP値(元のデータの分散と指定した共通因子のモデルに基づいて求めたデータの分散との間の有意差に関する検定統計量である。この検定統計量は、探索的に因子分析を行う際の因子の数を決める際の1つの参考材料となる)

# %% [markdown]
# ### 回転なし

# %%
# cutoff=0 は（値の小さいものも含め）全ての因子負荷の値を表示させる指示
# Uniquenesses：独自性 (=1-共通性) 
# 因子の回転によって因子負荷と寄与の値は変化するが、独自性の値は変化しない（ということは共通性の値も変化しない）
# 共通性の値が1以上，あるいは0に近い値でないか注意
# 

# 因子負荷量は相関係数なので0から±1の値をとる
print(fit0, cutoff=0)
# Out:
# Call:
# factanal(x = data, factors = 3, scores = "Bartlett", rotation = "none")
#
# Uniquenesses:
#        pop        urb        gdp       dist         hf date_first  detection
#      0.257      0.423      0.005      0.861      0.005      0.446      0.513
#        air
#      0.239
#
# Loadings:
#            Factor1 Factor2 Factor3
# pop        -0.249   0.821   0.085
# urb         0.636  -0.077   0.408
# gdp         0.878  -0.011   0.473
# dist       -0.071  -0.316  -0.184
# hf          0.873   0.003  -0.483
# date_first -0.439  -0.587  -0.129
# detection   0.507   0.454  -0.157
# air         0.484   0.629   0.361
#
#                Factor1 Factor2 Factor3
# SS loadings      2.689   1.726   0.836
# Proportion Var   0.336   0.216   0.105
# Cumulative Var   0.336   0.552   0.656
#
# Test of the hypothesis that 3 factors are sufficient.
# The chi square statistic is 46.05 on 7 degrees of freedom.
# The p-value is 8.55e-08

# %%
tmp = promax(fit0$loadings)$rotmat
solve(t(tmp)  %*% tmp)
# Out:
#      [,1]      [,2]      [,3]
# [1,] 1.0000000 0.3307958 0.5642382
# [2,] 0.3307958 1.0000000 0.3510472
# [3,] 0.5642382 0.3510472 1.0000000

# %% [markdown]
# ### varimax(直行回転)

# %%
# 因子間の相関を仮定しない
# distとhf、detectionに関しては独自因子が0.5を超えているので、これらの変数は共通因子で説明できない情報が半分を超えていると言える。
print(fit1, cutoff=0)
# Out:
# Call:
# factanal(x = data, factors = 3, scores = "Bartlett", rotation = "varimax")
#
# Uniquenesses:
#        pop        urb        gdp       dist         hf date_first  detection
#      0.257      0.423      0.005      0.861      0.005      0.446      0.513
#        air
#      0.239
#
# Loadings:
#            Factor1 Factor2 Factor3
# pop        -0.320   0.798  -0.067
# urb         0.740   0.076   0.156
# gdp         0.938   0.167   0.296
# dist       -0.095  -0.360   0.011
# hf          0.298  -0.123   0.944
# date_first -0.253  -0.611  -0.341
# detection   0.144   0.396   0.556
# air         0.428   0.726   0.224
#
#                Factor1 Factor2 Factor3
# SS loadings      1.895   1.872   1.484
# Proportion Var   0.237   0.234   0.186
# Cumulative Var   0.237   0.471   0.656
#
# Test of the hypothesis that 3 factors are sufficient.
# The chi square statistic is 46.05 on 7 degrees of freedom.
# The p-value is 8.55e-08

# %%
tmp = promax(fit1$loadings)$rotmat
solve(t(tmp)  %*% tmp)
# Out:
#      [,1]      [,2]
# [1,] 1.0000000 0.2854632
# [2,] 0.2854632 1.0000000

# %% [markdown]
# ### promax(斜交回転)

# %%
# 因子間の相関を仮定
# but, 相関はなかった
print(fit2, cutoff=0)
# Out:
# Call:
# factanal(x = data, factors = 2, scores = "Bartlett", rotation = "promax")
#
# Uniquenesses:
#        pop        urb        gdp       dist         hf date_first  detection
#      0.286      0.427      0.005      0.873      0.702      0.476      0.712
#        air
#      0.226
#
# Loadings:
#            Factor1 Factor2
# pop        -0.487   0.843
# urb         0.759  -0.008
# gdp         0.974   0.074
# dist       -0.023  -0.350
# hf          0.556  -0.039
# date_first -0.220  -0.630
# detection   0.216   0.434
# air         0.336   0.722
#
#                Factor1 Factor2
# SS loadings      2.279   1.947
# Proportion Var   0.285   0.243
# Cumulative Var   0.285   0.528
#
# Factor Correlations:
#         Factor1 Factor2
# Factor1   1.000  -0.285
# Factor2  -0.285   1.000
#
# Test of the hypothesis that 2 factors are sufficient.
# The chi square statistic is 104.92 on 13 degrees of freedom.
# The p-value is 1.83e-16

# %%
tmp = promax(fit2$loadings)$rotmat
solve(t(tmp)  %*% tmp)
# Out:
#      [,1]      [,2]
# [1,] 1.0000000 0.1648625
# [2,] 0.1648625 1.0000000

# %% [markdown]
# ## 結果の解釈
# - fit2では因子間の相関を仮定してpromax(斜交回転)で因子分析をした。
# しかし、相関は得られなかった。(相関係数-0.285)
# よって相関をないと仮定する
# - fi1では因子間の相関はないと仮定してvarimax(直行回転)で因子分析をした。
# 結果、因子間相関はなかった。(相関係数0.285)

# %%
unclass(fit1$loadings)
# Out:
#            Factor1    Factor2
# pop        -0.4020358  0.74297671
# urb         0.7430598  0.14301895
# gdp         0.9608995  0.26771818
# dist       -0.0534007 -0.35297926
# hf          0.5413911  0.07163641
# date_first -0.2719973 -0.67102067
# detection   0.2500562  0.47489143
# air         0.3939073  0.78635833

# %% [markdown]
# ### 因子負荷量の可視化
# - factor1・・・gdp, urb, hfが影響(先進国)
# - factor2・・・pop, air, data_firstが影響()

# %%
options(warn=-1)

# %%
# 因子負荷量の散布図(値は相関係数)
par(family="Osaka")
plot(fit1$loadings[,1:2],type="n", main="因子負荷量の可視化")
text(fit1$loadings[,1:2],colnames(data))
# Out:
# Plot with title “因子負荷量の可視化”

# %%
# 因子得点の散布図と因子負荷量の散布図
par(family="Osaka")
biplot(fit1$scores,fit1$loading,cex=2, main="因子得点の散布図と因子負荷量の散布図")
# Out:
# Plot with title “因子得点の散布図と因子負荷量の散布図”

# %%
# factor2（第二共通因子）までの累積寄与率は、0.537(0.5を超えておけばok?)
fit1
# Out:
# Call:
# factanal(x = data, factors = 2, scores = "Bartlett", rotation = "varimax")
#
# Uniquenesses:
#        pop        urb        gdp       dist         hf date_first  detection
#      0.286      0.427      0.005      0.873      0.702      0.476      0.712
#        air
#      0.226
#
# Loadings:
#            Factor1 Factor2
# pop        -0.402   0.743
# urb         0.743   0.143
# gdp         0.961   0.268
# dist               -0.353
# hf          0.541
# date_first -0.272  -0.671
# detection   0.250   0.475
# air         0.394   0.786
#
#                Factor1 Factor2
# SS loadings      2.225   2.068
# Proportion Var   0.278   0.259
# Cumulative Var   0.278   0.537
#
# Test of the hypothesis that 2 factors are sufficient.
# The chi square statistic is 104.92 on 13 degrees of freedom.
# The p-value is 1.83e-16

# %%
score_df = as.data.frame(fit1$score)
head(score_df)
# Out:
#   Factor1      Factor2
# 1  0.239466982 -0.8067330
# 2  0.001249695  0.4462947
# 3 -0.466127050 -0.6306339
# 4  0.306802239  0.2783279
# 5  0.792748876  1.4713779
# 6  1.161208313  0.3134312

# %% [markdown]
# ### 因子得点の高い国の確認

# %%
# 方法1

# %%
# Factor1の因子スコアが多い国の確認

#tmp = subset(score_df, (Factor1 >1.5) | (Factor1 < -1.5))
tmp = subset(score_df, Factor1 >1.5)
index_f1 = as.integer(rownames(tmp))

df[index_f1,]
# Out:
#     country    pop     urb     gdp       dist    hf   pf       ef   date_first
# 20  Brunei      428962  77.629  80920.05 3719566 5.69 4.760902 6.62 71
# 61  Iceland     353574  93.813  57303.06 7695516 8.41 9.084634 7.74 61
# 74  Kuwait     4137309 100.000  72897.56 5244993 6.19 5.968881 6.41 56
# 82  Luxembourg  607728  90.981 113337.42 7510071 8.56 9.263800 7.86 62
# 114 Qatar      2781677  99.135 126898.43 5117748 6.15 5.238267 7.07 62
# 123 Singapore  5638676 100.000 101531.63 3897578 8.11 7.502452 8.71 25
#     detection status air
# 20  30.5      1       1234.45
# 61  37.2      1       7819.74
# 74  47.5      1       6464.85
# 82  41.7      1       2099.10
# 114 32.7      1      29178.92
# 123 64.5      1      40401.51

# %%
# Factor2の因子スコアが多い国の確認
tmp = subset(score_df, Factor2 >1.5)
index_f2 = as.integer(rownames(tmp))

df[index_f2,]
# Out:
#     country     pop        urb    gdp       dist     hf   pf       ef
# 19  Brazil       209469333 86.569 16096.401 16335606 6.48 6.739923 6.23
# 26  Canada        37058856 81.411 48130.256  8965622 8.65 9.222964 8.08
# 48  France        66987244 80.444 45342.396  8550121 8.02 8.693716 7.35
# 52  Germany       82927922 77.312 53074.540  7170071 8.53 9.247491 7.82
# 62  India       1352617328 34.030  7762.882  2777278 6.64 6.368844 6.91
# 63  Indonesia    267663435 55.325 13079.619  4514121 6.83 6.384634 7.27
# 70  Japan        126529100 91.616 42797.459  3024190 8.28 8.699179 7.86
# 85  Malaysia      31528585 76.036 31782.153  3678054 6.52 5.698542 7.34
# 111 Philippines  106651922 46.907  8951.086  3345565 6.88 6.442997 7.32
# 116 Russia       144478050 74.433 27588.125  2870579 6.34 5.899881 6.78
# 127 South Korea   51635256 81.459 40111.776  2146566 8.20 8.814165 7.59
# 128 Spain         46723749 80.321 39715.439  8741360 8.12 8.686116 7.55
# 134 Thailand      69428524 49.949 19051.333  2392656 6.55 6.247297 6.86
# 142 UK            66488991 83.398 45973.574  7765919 8.47 8.849797 8.09
# 144 USA          327167434 82.256 62794.586 10196715 8.46 8.720049 8.19
# 147 Vietnam       95540395 35.919  7447.814  2220676 6.29 6.310973 6.27
#     date_first detection status air
# 19  58         82.4      1      102109.98
# 26  27         96.4      1       89380.00
# 48  26         75.3      1       70188.03
# 52  29         84.6      1      109796.20
# 62  31         47.4      1      164035.64
# 63  63         68.1      1      115154.10
# 70  16         70.1      1      126387.53
# 85  26         73.2      1       60481.77
# 111 31         63.6      1       43080.12
# 116 64         34.1      1       99327.31
# 127 21         92.1      1       88157.88
# 128 33         83.0      1       80672.10
# 134 14         81.0      1       76053.04
# 142 32         87.3      1      165388.61
# 144 22         98.2      1      889022.00
# 147 25         57.4      1       47049.67

# %%
# 方法2
df_factor_score = df
df_factor_score["factor1_score"] = score_df$Factor1
df_factor_score["factor2_score"] = score_df$Factor2

# %%
df_score1 = df_factor_score[order(df_factor_score$factor1_score, decreasing=T),]
df_score1[0:10,]
# Out:
#     country     pop     urb     gdp       dist    hf   pf       ef   date_first
# 82  Luxembourg   607728  90.981 113337.42 7510071 8.56 9.263800 7.86 62
# 114 Qatar       2781677  99.135 126898.43 5117748 6.15 5.238267 7.07 62
# 20  Brunei       428962  77.629  80920.05 3719566 5.69 4.760902 6.62 71
# 61  Iceland      353574  93.813  57303.06 7695516 8.41 9.084634 7.74 61
# 123 Singapore   5638676 100.000 101531.63 3897578 8.11 7.502452 8.71 25
# 74  Kuwait      4137309 100.000  72897.56 5244993 6.19 5.968881 6.41 56
# 66  Ireland     4853506  63.170  83203.39 8108624 8.52 8.904377 8.13 62
# 104 Norway      5314336  82.248  65510.59 6208684 8.44 9.259625 7.62 59
# 86  Malta        483530  94.612  42581.10 7705714 8.37 8.770593 7.97 69
# 133 Switzerland 8516543  73.797  68060.94 7539504 8.82 9.236934 8.40 58
#     detection status air       factor1_score factor2_score
# 82  41.7      1        2099.10 2.186788      -1.10327065
# 114 32.7      1       29178.92 1.989676      -0.07009626
# 20  30.5      1        1234.45 1.933759      -1.28993465
# 61  37.2      1        7819.74 1.578595      -1.00386176
# 123 64.5      1       40401.51 1.548142       0.87195333
# 74  47.5      1        6464.85 1.513236      -0.08974272
# 66  78.0      1      167598.63 1.457428       0.54903153
# 104 58.6      1       12277.22 1.378496       0.07995226
# 86  32.9      1        2576.90 1.370505      -1.19713148
# 133 59.1      1       28857.99 1.325843       0.38397954

# %%
df_score2 = df_factor_score[order(df_factor_score$factor2_score, decreasing=T),]
df_score2[0:10,]
# Out:
#     country     pop        urb    gdp       dist     hf   pf       ef
# 62  India       1352617328 34.030  7762.882  2777278 6.64 6.368844 6.91
# 144 USA          327167434 82.256 62794.586 10196715 8.46 8.720049 8.19
# 70  Japan        126529100 91.616 42797.459  3024190 8.28 8.699179 7.86
# 134 Thailand      69428524 49.949 19051.333  2392656 6.55 6.247297 6.86
# 147 Vietnam       95540395 35.919  7447.814  2220676 6.29 6.310973 6.27
# 127 South Korea   51635256 81.459 40111.776  2146566 8.20 8.814165 7.59
# 63  Indonesia    267663435 55.325 13079.619  4514121 6.83 6.384634 7.27
# 111 Philippines  106651922 46.907  8951.086  3345565 6.88 6.442997 7.32
# 52  Germany       82927922 77.312 53074.540  7170071 8.53 9.247491 7.82
# 142 UK            66488991 83.398 45973.574  7765919 8.47 8.849797 8.09
#     date_first detection status air       factor1_score factor2_score
# 62  31         47.4      1      164035.64 -1.3053998    2.976276
# 144 22         98.2      1      889022.00  0.5756215    2.833076
# 70  16         70.1      1      126387.53  0.3576022    2.438521
# 134 14         81.0      1       76053.04 -0.3385346    2.380117
# 147 25         57.4      1       47049.67 -1.0777390    2.072711
# 127 21         92.1      1       88157.88  0.4169459    2.024494
# 63  63         68.1      1      115154.10 -0.5492507    1.924415
# 111 31         63.6      1       43080.12 -0.8654619    1.898987
# 52  29         84.6      1      109796.20  0.7003818    1.855330
# 142 32         87.3      1      165388.61  0.5937265    1.805559

# %% [markdown]
# # 可視化(各変数の大小の確認)

# %%
library(classInt)

# %%
library(classInt)
#b5 n等分する、style=によって分け方変わるので注意
b5<-classIntervals(as.integer(df$air),n=5)

#c5はb5で分けした数(length(b5$brks)の色を用意
c5<-rev(heat.colors(length(b5$brks)-1))
#b.colで区分の色を決める
b.col<-findColours(b5,c5)

# %%
tmp = df
tmp["air"] = log(tmp["air"])

map_obj <- joinCountryData2Map(tmp, joinCode="NAME", nameJoinColumn="country")
par(family="Osaka")
mapCountryData(map_obj, nameColumnToPlot="air"
               , catMethod="fixedWidth"
               , mapTitle = "各国の空の移動量"
               #, colourPalette=heat.colors(7)
               #,colourPalette=c("#A6CEE3", "#B2DF8A", "#FB9A99") # 赤、緑、青
               #,colourPalette=b.col
               , addLegend = TRUE)
# Out:
# 149 codes from your data successfully matched countries in the map
# 1 codes from your data failed to match with a country code in the map
# 94 codes from the map weren't represented in your data
# Plot with title “各国の空の移動量”

# %%
tmp = df
tmp["pop"] = log(tmp["pop"])

map_obj <- joinCountryData2Map(tmp, joinCode="NAME", nameJoinColumn="country")
par(family="Osaka")
mapCountryData(map_obj, nameColumnToPlot="pop"
               , catMethod="fixedWidth"
               , mapTitle = "各国の人口"
               #, colourPalette=heat.colors(7)
               #,colourPalette=c("#A6CEE3", "#B2DF8A", "#FB9A99") # 赤、緑、青
               #,colourPalette=b.col
               , addLegend = TRUE)
# Out:
# 149 codes from your data successfully matched countries in the map
# 1 codes from your data failed to match with a country code in the map
# 94 codes from the map weren't represented in your data
# Plot with title “各国の人口”

# %%
map_obj <- joinCountryData2Map(df, joinCode="NAME", nameJoinColumn="country")
par(family="Osaka")
mapCountryData(map_obj, nameColumnToPlot="date_first"
               , catMethod="fixedWidth"
               , mapTitle = "中国でコロナ感染者が出てから各国でコロナ感染者が初めて出るまでの日数"
               , colourPalette=rev(heat.colors(7))
               #,colourPalette=c("#A6CEE3", "#B2DF8A", "#FB9A99") # 赤、緑、青
               #,colourPalette=b.col
               , addLegend = TRUE)
# Out:
# 149 codes from your data successfully matched countries in the map
# 1 codes from your data failed to match with a country code in the map
# 94 codes from the map weren't represented in your data
# Plot with title “中国でコロナ感染者が出てから各国でコロナ感染者が初めて出るまでの日数”

# %%
map_obj <- joinCountryData2Map(df_score1, joinCode="NAME", nameJoinColumn="country")
par(family="Osaka")
mapCountryData(map_obj, nameColumnToPlot="factor1_score"
               , catMethod="fixedWidth"
               , mapTitle = "facor1のスコア"
               , colourPalette=rev(heat.colors(7))
               #,colourPalette=c("#A6CEE3", "#B2DF8A", "#FB9A99") # 赤、緑、青
               #,colourPalette=b.col
               , addLegend = TRUE)
# Out:
# 149 codes from your data successfully matched countries in the map
# 1 codes from your data failed to match with a country code in the map
# 94 codes from the map weren't represented in your data
# Plot with title “facor1のスコア”

# %%
map_obj <- joinCountryData2Map(df_score2, joinCode="NAME", nameJoinColumn="country")
par(family="Osaka")
mapCountryData(map_obj, nameColumnToPlot="factor2_score"
               , catMethod="fixedWidth"
               , mapTitle = "facor2のスコア"
               , colourPalette=rev(heat.colors(7))
               #,colourPalette=c("#A6CEE3", "#B2DF8A", "#FB9A99") # 赤、緑、青
               #,colourPalette=b.col
               , addLegend = TRUE)
# Out:
# 149 codes from your data successfully matched countries in the map
# 1 codes from your data failed to match with a country code in the map
# 94 codes from the map weren't represented in your data
# Plot with title “facor2のスコア”

# %%
df[order(df$urb, decreasing=T),]
# Out:
#     country              pop        urb     gdp        dist     hf   pf
# 74  Kuwait                 4137309  100.000  72897.562  5244993 6.19 5.968881
# 123 Singapore              5638676  100.000 101531.630  3897578 8.11 7.502452
# 114 Qatar                  2781677   99.135 126898.426  5117748 6.15 5.238267
# 12  Belgium               11422068   98.001  51407.998  7548354 8.29 9.067695
# 145 Uruguay                3449299   95.334  23572.177 18135344 7.74 8.420754
# 86  Malta                   483530   94.612  42581.098  7705714 8.37 8.770593
# 61  Iceland                 353574   93.813  57303.061  7695516 8.41 9.084634
# 67  Israel                 8883800   92.418  39919.170  6247521 7.61 7.695323
# 4   Argentina             44494502   91.870  20610.569 19025624 6.86 8.044600
# 70  Japan                126529100   91.616  42797.459  3024190 8.28 8.699179
# 98  Netherlands           17231017   91.490  56328.941  7432851 8.50 9.283201
# 82  Luxembourg              607728   90.981 113337.420  7510071 8.56 9.263800
# 71  Jordan                 9956011   90.979   9478.905  6104179 6.84 6.234962
# 49  Gabon                  2119275   89.370  17875.761 10233362 5.99 6.102799
# 9   Bahrain                1569439   89.287  47303.049  5138295 6.63 5.910895
# 78  Lebanon                6848925   88.593  13081.107  6057921 6.74 6.519808
# 146 Venezuela             28870195   88.208  18102.500 15058065 3.80 5.027017
# 39  Denmark                5797446   87.874  55671.165  6950551 8.56 9.238445
# 30  Chile                 18729160   87.564  25222.528 19577066 8.15 8.410726
# 132 Sweden                10183175   87.431  53208.884  6323651 8.50 9.445978
# 19  Brazil               209469333   86.569  16096.401 16335606 6.48 6.739923
# 99  New Zealand            4885500   86.538  41005.421 11071536 8.88 9.269332
# 141 United Arab Emirates   9630959   86.522  75075.257  4911772 6.13 5.087239
# 5   Australia             24992369   86.012  51663.365  7608913 8.62 9.160533
# 47  Finland                5518050   85.382  48416.936  5823421 8.53 9.268558
# 105 Oman                   4829483   84.539  41859.934  4935611 5.98 5.198332
# 118 Saudi Arabia          33699947   83.844  55335.680  5774072 5.42 4.316478
# 142 UK                    66488991   83.398  45973.574  7765919 8.47 8.849797
# 8   Bahamas                 385640   83.025  32087.729 13276138 7.56 7.871205
# 144 USA                  327167434   82.256  62794.586 10196715 8.46 8.720049
# ⋮   ⋮                    ⋮          ⋮       ⋮          ⋮        ⋮    ⋮
# 15  Bhutan                   754394 40.895  10167.9341  1621388 6.53 6.286280
# 88  Mauritius               1265303 40.793  23750.9880  7927009 7.52 6.979448
# 83  Madagascar             26262368 37.191   1891.3207  8620110 6.32 6.507700
# 106 Pakistan              212215030 36.666   5567.0556  3277290 5.69 5.471811
# 148 Yemen                  28498687 36.642   2575.1264  5972543 4.30 2.750150
# 10  Bangladesh            161356039 36.632   4371.7550  1918841 5.77 5.365573
# 75  Kyrgyzstan              6315800 36.351   3884.7088  2580872 6.98 7.045888
# 56  Guinea                 12414318 36.140   2504.8697 11454618 5.61 5.365422
# 94  Mozambique             29495962 35.988   1459.6984  9315084 6.24 6.886214
# 147 Vietnam                95540395 35.919   7447.8143  2220676 6.29 6.310973
# 76  Laos                    7061507 35.004   7439.5994  2001266 6.20 5.736234
# 130 Sudan                  41801533 34.642   4767.6898  7544969 4.32 3.966534
# 62  India                1352617328 34.030   7762.8818  2777278 6.64 6.368844
# 143 Tanzania               56318348 33.776   3240.2629  8585459 6.26 5.748136
# 150 Zimbabwe               14439018 32.209   3029.7930  9898131 5.65 5.608024
# 95  Myanmar                53708395 30.579   6674.0286  1848397 5.44 5.258742
# 22  Burkina Faso           19751535 29.358   1984.8843 10558298 6.73 7.386563
# 73  Kenya                  51393010 27.030   3467.5565  7847895 6.85 6.646510
# 58  Guyana                   779004 26.606   8640.7374 15092264 6.74 7.160822
# 139 Uganda                 42723139 23.774   2038.0739  8276651 6.61 5.824176
# 24  Cambodia               16249798 23.388   4360.8544  2643780 7.13 6.824764
# 29  Chad                   15477751 23.059   1968.2583  8588725 5.46 5.490401
# 45  Ethiopia              109224559 20.763   2022.1380  7146991 5.25 4.772704
# 97  Nepal                  28087871 19.740   3089.5564  2081805 6.51 6.534789
# 129 Sri Lanka              21670000 18.476  13473.6631  3971847 6.41 6.245851
# 117 Rwanda                 12301939 17.211   2251.5564  8713402 6.82 6.377693
# 84  Malawi                 18143315 16.937   1310.9956  9123415 6.60 7.132714
# 101 Niger                  22442948 16.425   1063.4218  9261430 5.87 5.916132
# 108 Papua New Guinea        8606316 13.169   4336.2447  6425499 6.60 6.841671
# 23  Burundi                11175378 13.032    744.1821  8810122 5.56 4.953952
#     ef   date_first detection status air
# 74  6.41 56         47.5      1        6464.85
# 123 8.71 25         64.5      1       40401.51
# 114 7.07 62         32.7      1       29178.92
# 12  7.51 36         62.5      1       13639.49
# 145 7.05 76         33.5      1         563.63
# 86  7.97 69         32.9      1        2576.90
# 61  7.74 61         37.2      1        7819.74
# 67  7.53 54         52.4      1        7404.37
# 4   5.67 65         74.9      1        1516.63
# 70  7.86 16         70.1      1      126387.53
# 98  7.72 60         86.0      1       43996.04
# 82  7.86 62         41.7      1        2099.10
# 71  7.44 64         42.9      1        3383.80
# 49  5.88 74          6.1      1          77.32
# 9   7.35 56         45.8      1        5877.00
# 78  6.97 54         62.0      1        2981.94
# 146 2.58 76          8.7      1        2137.77
# 39  7.89 59         86.0      1        6428.70
# 30  7.89 65         72.7      1       19517.19
# 132 7.56 33         86.0      1       11623.92
# 19  6.23 58         82.4      1      102109.98
# 99  8.50 60         36.7      1       17249.05
# 141 7.17 28         31.6      1       95533.07
# 5   8.07 26         97.3      1       75667.65
# 47  7.80 31         61.6      1       13364.84
# 105 6.76 57         41.1      1       10438.24
# 118 6.52 64         74.4      1       39141.66
# 142 8.09 32         87.3      1      165388.61
# 8   7.25 77         21.8      1        1197.12
# 144 8.19 22         98.2      1      889022.00
# ⋮   ⋮    ⋮          ⋮         ⋮      ⋮
# 15  6.77  67        42.8      1         275.85
# 88  8.07  81        42.3      1        1745.29
# 83  6.14  82        41.9      1         541.29
# 106 5.91  59        41.7      1        6880.64
# 148 5.84 102         9.0      1         336.31
# 10  6.18  70        50.9      1        5984.16
# 75  6.92  80        64.7      1         709.20
# 56  5.86  75        57.2      1          58.50
# 94  5.60  84        29.3      1         540.12
# 147 6.27  25        57.4      1       47049.67
# 76  6.67  86        70.4      1        1251.96
# 130 4.67  75         7.0      1         269.96
# 62  6.91  31        47.4      1      164035.64
# 143 6.77  78        42.0      1        1481.56
# 150 5.69  82        65.6      1         282.54
# 95  5.63  78        59.2      1        3407.79
# 22  6.07  72        33.3      1         151.53
# 73  7.05  75        68.6      1        5935.83
# 58  6.32  74        20.3      1          26.07
# 139 7.39  83        50.3      1          21.54
# 24  7.44  29        57.7      1        1411.06
# 29  5.42  81        36.5      1          28.33
# 45  5.72  75        33.7      1       11501.24
# 97  6.49  26        22.0      1        3296.95
# 129 6.57  29        43.0      1        5882.38
# 117 7.26  76        36.0      1        1073.53
# 84  6.06  95        23.3      1          10.54
# 101 5.83  82        44.4      1          14.71
# 108 6.36  82        31.8      1         964.71
# 23  6.17  93        11.4      1          12.00

# %%
tmp = df[order(df$date_first),]
tmp[40:60,]
# Out:
#     country            pop       urb    gdp        dist     hf   pf       ef
# 103 Macedonia            2082958 57.963  16358.662  6851849 7.34 7.662440 7.02
# 104 Norway               5314336 82.248  65510.585  6208684 8.44 9.259625 7.62
# 106 Pakistan           212215030 36.666   5567.056  3277290 5.69 5.471811 5.91
# 115 Romania             19473936 53.998  28206.357  6422259 8.11 8.536526 7.68
# 11  Belarus              9485386 78.595  19994.804  5952246 6.65 6.659028 6.64
# 44  Estonia              1320884 68.880  35973.776  5972791 8.46 9.021806 7.89
# 81  Lithuania            2789533 67.679  35461.359  6160471 8.32 8.757218 7.88
# 98  Netherlands         17231017 91.490  56328.941  7432851 8.50 9.283201 7.72
# 99  New Zealand          4885500 86.538  41005.421 11071536 8.88 9.269332 8.50
# 102 Nigeria            195874740 50.344   5990.850  9889816 6.38 5.897667 6.86
# 7   Azerbaijan           9942334 55.680  18044.137  4849217 6.22 6.104661 6.34
# 61  Iceland               353574 93.813  57303.061  7695516 8.41 9.084634 7.74
# 89  Mexico             126190788 80.156  19844.646 12761325 6.65 6.379533 6.93
# 41  Ecuador             17084357 63.821  11734.387 16104587 6.82 7.358018 6.28
# 66  Ireland              4853506 63.170  83203.395  8108624 8.52 8.904377 8.13
# 82  Luxembourg            607728 90.981 113337.420  7510071 8.56 9.263800 7.86
# 114 Qatar                2781677 99.135 126898.426  5117748 6.15 5.238267 7.07
# 37  Czech Republic      10629928 73.792  39743.597  6921795 8.34 8.922165 7.75
# 40  Dominican Republic  10627165 81.074  17748.185 13837191 6.95 6.982170 6.92
# 63  Indonesia          267663435 55.325  13079.619  4514121 6.83 6.384634 7.27
# 71  Jordan               9956011 90.979   9478.905  6104179 6.84 6.234962 7.44
#     date_first detection status air
# 103 59         41.7      1          86.87
# 104 59         58.6      1       12277.22
# 106 59         41.7      1        6880.64
# 115 59         42.8      1        4908.23
# 11  60         28.9      1        2760.17
# 44  60         77.6      1          31.98
# 81  60         81.5      1          26.03
# 98  60         86.0      1       43996.04
# 99  60         36.7      1       17249.05
# 102 60         44.6      1        8169.19
# 7   61         45.0      1        2279.55
# 61  61         37.2      1        7819.74
# 89  61         71.2      1       64569.64
# 41  62         71.2      1        5365.26
# 66  62         78.0      1      167598.63
# 82  62         41.7      1        2099.10
# 114 62         32.7      1       29178.92
# 37  63         44.9      1        5727.20
# 40  63         37.1      1          11.90
# 63  63         68.1      1      115154.10
# 71  64         42.9      1        3383.80
